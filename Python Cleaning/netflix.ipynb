# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("netflix_titles.csv")
df = df.head(2000)

# %%
df
# Out:
#      show_id     type                               title            director  \
# 0         s1    Movie                Dick Johnson Is Dead     Kirsten Johnson
# 1         s2  TV Show                       Blood & Water                 NaN
# 2         s3  TV Show                           Ganglands     Julien Leclercq
# 3         s4  TV Show               Jailbirds New Orleans                 NaN
# 4         s5  TV Show                        Kota Factory                 NaN
# ...      ...      ...                                 ...                 ...
# 1995   s1996    Movie              The Devil All The Time      Antonio Campos
# 1996   s1997    Movie                       The Paramedic       Carles Torras
# 1997   s1998    Movie                            The Take       James Watkins
# 1998   s1999  TV Show                    Call the Midwife  Philippa Lowthorpe
# 1999   s2000    Movie  Hope Frozen: A Quest to Live Twice        Pailin Wedel
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                   NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...                                                 ...
# 1995  Tom Holland, Bill Skarsgård, Riley Keough, Rob...
# 1996  Mario Casas, Déborah François, Guillermo Pfeni...
# 1997  Idris Elba, Richard Madden, Charlotte Le Bon, ...
# 1998  Vanessa Redgrave, Bryony Hannah, Helen George,...
# 1999                                                NaN
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 1                                          South Africa  September 24, 2021
# 2                                                   NaN  September 24, 2021
# 3                                                   NaN  September 24, 2021
# 4                                                 India  September 24, 2021
# ...                                                 ...                 ...
# 1995                                      United States  September 16, 2020
# 1996                                              Spain  September 16, 2020
# 1997  United Kingdom, France, United States, Belgium...  September 16, 2020
# 1998                                     United Kingdom  September 15, 2020
# 1999                            Thailand, United States  September 15, 2020
#
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# ...            ...    ...        ...
# 1995          2020      R    139 min
# 1996          2020  TV-MA     94 min
# 1997          2016      R     92 min
# 1998          2020  TV-MA  9 Seasons
# 1999          2020  TV-PG     80 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 1995                                  Dramas, Thrillers
# 1996            Dramas, International Movies, Thrillers
# 1997           Action & Adventure, International Movies
# 1998  British TV Shows, International TV Shows, TV D...
# 1999                Documentaries, International Movies
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 1995  Sinister characters converge around a young ma...
# 1996  Unable to face his new reality in a wheelchair...
# 1997  After a mix-up lands him in hot water, a skill...
# 1998  This period drama set in impoverished East Lon...
# 1999  A Thai scientist and his family decide to cryo...
#
# [2000 rows x 12 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df['country'].fillna("Unknown", inplace=True)
# Out:
# C:\Users\Shruti\AppData\Local\Temp\ipykernel_22552\3206245367.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna("Unknown", inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df['director'].fillna("Unknown",inplace = True)
# Out:
# C:\Users\Shruti\AppData\Local\Temp\ipykernel_22552\920115892.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna("Unknown",inplace = True)

# %%
df['cast'].fillna("Unknown", inplace = True)
# Out:
# C:\Users\Shruti\AppData\Local\Temp\ipykernel_22552\2275272973.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna("Unknown", inplace = True)

# %%
df['duration'] = df['duration'].astype(str)

# %%
df['country'] = df['country'].str.strip()

# %%
df['director'] = df['director'].str.strip()

# %%
df['title'] = df['title'].str.strip()

# %%
df.shape
# Out:
# (2000, 12)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.to_csv("cleaned_netflix.csv", index=False)

# %%
df.shape
# Out:
# (2000, 12)
